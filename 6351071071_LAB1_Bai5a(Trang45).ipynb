# %% [markdown]
# <a href="https://colab.research.google.com/github/tuilatoan15/6351071071_Lab1/blob/main/6351071071_LAB1_Bai5a(Trang45).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1

# %%
print("Nguyễn Hữu Toàn – 6351071071")

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import warnings
warnings.filterwarnings('ignore')

df = pd.read_excel('Online Retail.xlsx')
df.info()
# Out:
# Nguyễn Hữu Toàn – 6351071071
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# # 2

# %%
print("Nguyễn Hữu Toàn – 6351071071")
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')

df.head(10)
# Out:
# Nguyễn Hữu Toàn – 6351071071
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# ...

# %% [markdown]
# # 3

# %%
df[df.InvoiceNo.str.contains('C', na=False)].head()

df = df[~df['InvoiceNo'].str.contains('C')]

# %% [markdown]
# # 4

# %%
print("Nguyễn Hữu Toàn – 6351071071")

import matplotlib.pyplot as plt

df['Country'].value_counts().plot(kind='barh', figsize=(15,10))
plt.show()
# Out:
# Nguyễn Hữu Toàn – 6351071071

# %% [markdown]
# # 5

# %%
print("Nguyễn Hữu Toàn – 6351071071")

basket = df[df['Country'] == "United Kingdom"].groupby(['InvoiceNo', 'Description'])['Quantity']
# Out:
# Nguyễn Hữu Toàn – 6351071071

# %% [markdown]
# # 6

# %%
print("Nguyễn Hữu Toàn – 6351071071")

basket = basket.sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')

basket.head(10)
# Out:
# Nguyễn Hữu Toàn – 6351071071
# Description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# InvoiceNo
# 536365                         0.0                      0.0
# 536366                         0.0                      0.0
# 536367                         0.0                      0.0
# 536368                         0.0                      0.0
# 536369                         0.0                      0.0
# 536371                         0.0                      0.0
# 536372                         0.0                      0.0
# 536373                         0.0                      0.0
# 536374                         0.0                      0.0
# 536375                         0.0                      0.0
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536365                          0.0                         0.0
# 536366                          0.0                         0.0
# ...

# %% [markdown]
# # 7

# %%
print("Nguyễn Hữu Toàn – 6351071071")

def encode_data(datapoint):
    if datapoint <= 0:
        return 0
    if datapoint >= 1:
        return 1

basket = basket.applymap(encode_data)
basket.head(10)
# Out:
# Nguyễn Hữu Toàn – 6351071071
# Description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# InvoiceNo
# 536365                           0                        0
# 536366                           0                        0
# 536367                           0                        0
# 536368                           0                        0
# 536369                           0                        0
# 536371                           0                        0
# 536372                           0                        0
# 536373                           0                        0
# 536374                           0                        0
# 536375                           0                        0
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536365                            0                           0
# 536366                            0                           0
# ...

# %% [markdown]
# # 8

# %%
print("Nguyễn Hữu Toàn – 6351071071")

basket.drop('POSTAGE', inplace=True, axis=1)
basket.head(10)
# Out:
# Nguyễn Hữu Toàn – 6351071071
# Description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# InvoiceNo
# 536365                           0                        0
# 536366                           0                        0
# 536367                           0                        0
# 536368                           0                        0
# 536369                           0                        0
# 536371                           0                        0
# 536372                           0                        0
# 536373                           0                        0
# 536374                           0                        0
# 536375                           0                        0
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536365                            0                           0
# 536366                            0                           0
# ...

# %% [markdown]
# # 9

# %%
print("Nguyễn Hữu Toàn – 6351071071")

from mlxtend.frequent_patterns import apriori

itemsets = apriori(basket, min_support=0.05, use_colnames=True)
itemsets.head(10)
# Out:
# Nguyễn Hữu Toàn – 6351071071
#     support                             itemsets
# 0  0.073445      (ASSORTED COLOUR BIRD ORNAMENT)
# 1  0.050035    (GREEN REGENCY TEACUP AND SAUCER)
# 2  0.062356              (HEART OF WICKER SMALL)
# 3  0.053999             (JAM MAKING SET PRINTED)
# 4  0.053517           (JAM MAKING SET WITH JARS)
# 5  0.062088            (JUMBO BAG PINK POLKADOT)
# 6  0.103820            (JUMBO BAG RED RETROSPOT)
# 7  0.060695  (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 8  0.060535             (JUMBO STORAGE BAG SUKI)
# 9  0.065142            (LUNCH BAG  BLACK SKULL.)

# %% [markdown]
# # 10

# %%
print("Nguyễn Hữu Toàn – 6351071071")

from mlxtend.frequent_patterns import association_rules

rules = association_rules(itemsets, metric="confidence", min_threshold=0.5)

rules.info()

rules["antecedents"] = rules["antecedents"].apply(lambda x: list(x)[0]).astype("unicode")
rules["consequents"] = rules["consequents"].apply(lambda x: list(x)[0]).astype("unicode")

for i in range(len(rules)):
    print(rules.loc[i, 'antecedents'], '', rules.loc[i, 'consequents'],
          [rules.loc[i, 'support'], rules.loc[i, 'confidence']])
# Out:
# Nguyễn Hữu Toàn – 6351071071
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   antecedents         0 non-null      object
#  1   consequents         0 non-null      object
#  2   antecedent support  0 non-null      object
#  3   consequent support  0 non-null      object
#  4   support             0 non-null      object
#  5   confidence          0 non-null      object
#  6   lift                0 non-null      object
#  7   representativity    0 non-null      object
#  8   leverage            0 non-null      object
#  9   conviction          0 non-null      object
#  10  zhangs_metric       0 non-null      object
#  11  jaccard             0 non-null      object
#  12  certainty           0 non-null      object
#  13  kulczynski          0 non-null      object
# dtypes: object(14)
# memory usage: 132.0+ bytes

# %% [markdown]
# # 11

# %%
if not rules.empty:
    support = rules['support'].values
    confidence = rules['confidence'].values

    plt.figure(figsize=(6,6))
    plt.title('Association Rules')
    plt.xlabel('support')
    plt.ylabel('confidence')
    sns.scatterplot(x=support, y=confidence)
    plt.xlim(0, max(support)*1.1)
    plt.ylim(0, 1)
    plt.show()
else:
    print("Không có luật nào thỏa min_support/min_conf.")
# Out:
# Không có luật nào thỏa min_support/min_conf.

# %% [markdown]
# # 12

# %%
print("Nguyễn Hữu Toàn – 6351071071")

from mlxtend.frequent_patterns import fpgrowth

itemsets = fpgrowth(basket, min_support=0.05, use_colnames=True)
itemsets.head(10)
# Out:
# Nguyễn Hữu Toàn – 6351071071
#     support                              itemsets
# 0  0.116034  (WHITE HANGING HEART T-LIGHT HOLDER)
# 1  0.073445       (ASSORTED COLOUR BIRD ORNAMENT)
# 2  0.053517            (JAM MAKING SET WITH JARS)
# 3  0.060267      (PAPER CHAIN KIT 50'S CHRISTMAS)
# 4  0.057642   (WOODEN PICTURE FRAME WHITE FINISH)
# 5  0.050463          (WOODEN FRAME ANTIQUE WHITE)
# 6  0.074570             (LUNCH BAG RED RETROSPOT)
# 7  0.062088             (JUMBO BAG PINK POLKADOT)
# 8  0.060535              (JUMBO STORAGE BAG SUKI)
# 9  0.060481     (PACK OF 72 RETROSPOT CAKE CASES)
