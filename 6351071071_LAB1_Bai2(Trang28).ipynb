# %% [markdown]
# <a href="https://colab.research.google.com/github/tuilatoan15/6351071071_Lab1/blob/main/6351071071_LAB1_Bai2(Trang28).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from google.colab import files

print("Nguyễn Hữu Toàn – 6351071071")

df = pd.read_csv('bank.csv', sep=';')

df.head(12)
# Out:
# Nguyễn Hữu Toàn – 6351071071
#     age            job  marital  education default  balance housing loan  \
# 0    30     unemployed  married    primary      no     1787      no   no
# 1    33       services  married  secondary      no     4789     yes  yes
# 2    35     management   single   tertiary      no     1350     yes   no
# 3    30     management  married   tertiary      no     1476     yes  yes
# 4    59    blue-collar  married  secondary      no        0     yes   no
# 5    35     management   single   tertiary      no      747      no   no
# 6    36  self-employed  married   tertiary      no      307     yes   no
# 7    39     technician  married  secondary      no      147     yes   no
# 8    41   entrepreneur  married   tertiary      no      221     yes   no
# 9    43       services  married    primary      no      -88     yes  yes
# 10   39       services  married  secondary      no     9374     yes   no
# ...

# %%
print("Nguyễn Hữu Toàn – 6351071071")
df.head(12)
# Out:
# Nguyễn Hữu Toàn – 6351071071
#     age            job  marital  education default  balance housing loan  \
# 0    30     unemployed  married    primary      no     1787      no   no
# 1    33       services  married  secondary      no     4789     yes  yes
# 2    35     management   single   tertiary      no     1350     yes   no
# 3    30     management  married   tertiary      no     1476     yes  yes
# 4    59    blue-collar  married  secondary      no        0     yes   no
# 5    35     management   single   tertiary      no      747      no   no
# 6    36  self-employed  married   tertiary      no      307     yes   no
# 7    39     technician  married  secondary      no      147     yes   no
# 8    41   entrepreneur  married   tertiary      no      221     yes   no
# 9    43       services  married    primary      no      -88     yes  yes
# 10   39       services  married  secondary      no     9374     yes   no
# ...

# %%
print("Nguyễn Hữu Toàn – 6351071071")
df.info()
# Out:
# Nguyễn Hữu Toàn – 6351071071
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
print("Nguyễn Hữu Toàn – 6351071071")
df.describe()
# Out:
# Nguyễn Hữu Toàn – 6351071071
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# ...

# %% [markdown]
# # 2

# %%
print("Nguyễn Hữu Toàn – 6351071071")
total = df.isnull().sum().sort_values(ascending=False)
percent_1 = df.isnull().sum() / df.isnull().count() * 100
percent_2 = round(percent_1, 1).sort_values(ascending=False)
missing_data = pd.concat([total, percent_2], axis=1, keys=['Total', '%'])
missing_data.head(5)
# Out:
# Nguyễn Hữu Toàn – 6351071071
#            Total    %
# age            0  0.0
# job            0  0.0
# marital        0  0.0
# education      0  0.0
# default        0  0.0

# %% [markdown]
# # 3

# %%
import matplotlib.pyplot as plt
import seaborn as sns
survived = 'Subscribed (Yes)'
not_survived = 'Not Subscribed (No)'
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
married_data = df[df['marital']=='married']
single_data = df[df['marital']=='single']
ax = sns.histplot(married_data[married_data['y']=='yes'].age.dropna(),
bins=18, label=survived, ax=axes[0], kde=False, color='g')
ax = sns.histplot(married_data[married_data['y']=='no'].age.dropna(),
bins=40, label=not_survived, ax=axes[0], kde=False, color='y')
ax.legend()
ax.set_title('Married')
ax = sns.histplot(single_data[single_data['y']=='yes'].age.dropna(),
bins=18, label=survived, ax=axes[1], kde=False, color='g')
ax = sns.histplot(single_data[single_data['y']=='no'].age.dropna(),
bins=40, label=not_survived, ax=axes[1], kde=False, color='y')
ax.legend()
_ = ax.set_title('Single')
print("Nguyễn Hữu Toàn – 6351071071")
# Out:
# Nguyễn Hữu Toàn – 6351071071

# %% [markdown]
# # 4

# %%
print("Nguyễn Hữu Toàn – 6351071071")

if 'y_numeric' not in df.columns:
    df['y_numeric'] = df['y'].map({'yes': 1, 'no': 0})
    print("Đã tạo cột 'y_numeric'.")

print(df[['y', 'y_numeric']].head())
# Out:
# Nguyễn Hữu Toàn – 6351071071
# Đã tạo cột 'y_numeric'.
#     y  y_numeric
# 0  no          0
# 1  no          0
# 2  no          0
# 3  no          0
# 4  no          0

# %%
import seaborn as sns
edu_order = ['primary', 'secondary', 'tertiary', 'unknown']
FacetGrid = sns.FacetGrid(df, row='contact', height=4.5, aspect=1.6)
FacetGrid.map(sns.pointplot, 'education', 'y_numeric', 'marital',
palette=None, order=edu_order, hue_order=None)
FacetGrid.add_legend()
print("Nguyễn Hữu Toàn – 6351071071")
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#1f77b4'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#1f77b4'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#1f77b4'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# Nguyễn Hữu Toàn – 6351071071

# %%
import seaborn as sns
import matplotlib.pyplot as plt

edu_order = ['primary', 'secondary', 'tertiary', 'unknown']
palette_colors = ['blue', 'orange', 'green', 'pink']

sns.barplot(
    x='education',
    y='y_numeric',
    data=df,
    order=edu_order,
    palette=palette_colors
)

print("Nguyễn Hữu Toàn – 6351071071")
plt.show()
# Out:
# /tmp/ipython-input-806242364.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# Nguyễn Hữu Toàn – 6351071071

# %%
import matplotlib.pyplot as plt

grid = sns.FacetGrid(df, col='y', row='education', height=4.2,
aspect=1.6)
grid.map(plt.hist, 'age', alpha=.5, bins=20)
grid.add_legend()
print("Nguyễn Hữu Toàn – 6351071071")
# Out:
# Nguyễn Hữu Toàn – 6351071071

# %% [markdown]
# # 5

# %%
if 'housing_num' not in df.columns:
    df['housing_num'] = df['housing'].map({'yes': 1, 'no': 0})

if 'loan_num' not in df.columns:
    df['loan_num'] = df['loan'].map({'yes': 1, 'no': 0})

for dataset in [df]:
    dataset['debt_indicators'] = dataset['housing_num'] + dataset['loan_num']
    dataset['no_debt'] = 0
    dataset.loc[dataset['debt_indicators'] == 0, 'no_debt'] = 1
    dataset['no_debt'] = dataset['no_debt'].astype(int)

print("Thống kê cột 'no_debt' (1 = không nợ, 0 = có nợ):")
print(df['no_debt'].value_counts())

print("\nThống kê cột 'debt_indicators' (số lượng nợ):")
print(df['debt_indicators'].value_counts())

print("Nguyễn Hữu Toàn – 6351071071")
# Out:
# Thống kê cột 'no_debt' (1 = không nợ, 0 = có nợ):
# no_debt
# 0    2844
# 1    1677
# Name: count, dtype: int64
#
# Thống kê cột 'debt_indicators' (số lượng nợ):
# debt_indicators
# 1    2438
# 0    1677
# 2     406
# Name: count, dtype: int64
# Nguyễn Hữu Toàn – 6351071071

# %%
import seaborn as sns

if 'y_numeric' not in df.columns:
    df['y_numeric'] = df['y'].map({'yes': 1, 'no': 0})

axes = sns.catplot(
    x='debt_indicators',
    y='y_numeric',
    data=df,
    aspect=2.5,
    kind='point'
)

print("Nguyễn Hữu Toàn – 6351071071")
# Out:
# Nguyễn Hữu Toàn – 6351071071

# %% [markdown]
# # 6

# %%
import re

poutcome_map = {"failure": 0, "unknown": 1, "other": 2, "success": 3}

for dataset in [df]:
    dataset['poutcome_num'] = dataset['poutcome'].map(poutcome_map)
    dataset['poutcome_num'] = dataset['poutcome_num'].fillna(1)
    dataset['poutcome_num'] = dataset['poutcome_num'].astype(int)

df = df.drop(['poutcome'], axis=1)

print("Nguyễn Hữu Toàn – 6351071071")
print("Đã map 'poutcome' thành 'poutcome_num' và bỏ cột gốc:")
print(df['poutcome_num'].value_counts())
# Out:
# Nguyễn Hữu Toàn – 6351071071
# Đã map 'poutcome' thành 'poutcome_num' và bỏ cột gốc:
# poutcome_num
# 1    3705
# 0     490
# 2     197
# 3     129
# Name: count, dtype: int64

# %%
print("Nguyễn Hữu Toàn – 6351071071")
df['job'].describe()
# Out:
# Nguyễn Hữu Toàn – 6351071071
# count           4521
# unique            12
# top       management
# freq             969
# Name: job, dtype: object

# %%
df = df.drop(['duration'], axis=1)
df = df.drop(['contact'], axis=1)
print(df.columns)
print("Nguyễn Hữu Toàn – 6351071071")
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'day', 'month', 'campaign', 'pdays', 'previous', 'y',
#        'y_numeric', 'housing_num', 'loan_num', 'debt_indicators', 'no_debt',
#        'poutcome_num'],
#       dtype='object')
# Nguyễn Hữu Toàn – 6351071071

# %%
import numpy as np

for dataset in [df]:
    mean = dataset["age"].mean()
    std = dataset["age"].std()
    is_null = dataset["age"].isnull().sum()
    rand_age = np.random.randint(mean - std, mean + std, size=is_null)
    age_slice = dataset["age"].copy()
    age_slice[np.isnan(age_slice)] = rand_age
    dataset["age"] = age_slice
    dataset["age"] = dataset["age"].astype(int)

print(f"Số lượng 'age' bị thiếu: {df['age'].isnull().sum()}")
print("Nguyễn Hữu Toàn – 6351071071")
# Out:
# Số lượng 'age' bị thiếu: 0
# Nguyễn Hữu Toàn – 6351071071

# %%
print("Nguyễn Hữu Toàn – 6351071071")
df['education'].describe()
# Out:
# Nguyễn Hữu Toàn – 6351071071
# count          4521
# unique            4
# top       secondary
# freq           2306
# Name: education, dtype: object

# %%
common_value = df['education'].describe().top
print(f"Giá trị phổ biến nhất của 'education' là: {common_value}")

for dataset in [df]:
    dataset['education'] = dataset['education'].replace('unknown', common_value)

print("\nĐã thay thế 'unknown' trong 'education':")
print(df['education'].value_counts())
print("Nguyễn Hữu Toàn – 6351071071")
# Out:
# Giá trị phổ biến nhất của 'education' là: secondary
#
# Đã thay thế 'unknown' trong 'education':
# education
# secondary    2493
# tertiary     1350
# primary       678
# Name: count, dtype: int64
# Nguyễn Hữu Toàn – 6351071071
